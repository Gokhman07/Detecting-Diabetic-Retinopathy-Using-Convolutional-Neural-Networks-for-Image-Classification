# %%
import json

# %%
with open('merged_full_random.ipynb') as f:
    nb1 = json.load(f)

with open('merged_full_even.ipynb') as f:
    nb2 = json.load(f)

nb1['cells'] += nb2['cells']

with open('merged_full_even_radndom.ipynb', 'w') as f:
    json.dump(nb1, f)
